# %%
import yfinance as yf
import pandas as pd
import numpy as np
import scipy

import datetime
import os

import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA

# %%
# Define portfolio asset class breakdown
assets = {
    #Growth Assets
    'BTC-USD': 'BTC',
    'QQQM': 'Nasdaq-100 ETF',

    #Hedging Assets
    'GLD': 'Gold Commodity',
    'BND': 'Vanguard Total Bond Market Index Fund',

    #Stable Income
    'SCHV': 'High Yield Dividend-Paying ETF (10%'
}

tickers = ['BTC-USD', 'QQQM', 'GLD', 'BND', 'SCHV']
start_date = '2020-01-01'
end_date = datetime.datetime.today().strftime('%Y-%m-%d')
# Out:
# ['BTC-USD', 'QQQM', 'GLD', 'BND', 'SCHV']

# %%
# Download asset date from yfinance

asset_data = pd.DataFrame()

for symbol in tickers:
    asset_data = yf.download(symbol, start=start_date, end=end_date)
    asset_data['ticker'] = symbol  # Add a column for the ticker symbol

    asset_data.rename(columns={
        'Date': 'date',
        'Adj Close': 'adj_close',
        'Close': 'close',
        'High': 'high',
        'Low': 'low',
        'Open': 'open',
        'Volume': 'volume'
    }, inplace=True)

    asset_data.to_csv(f'{symbol}.csv')

#print(asset_data.head)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# <bound method NDFrame.head of Price           close       high        low       open   volume ticker
# Ticker           SCHV       SCHV       SCHV       SCHV     SCHV
# Date
# 2020-01-02  15.661394  15.661394  15.575883  15.656211  1887300   SCHV
# 2020-01-03  15.531830  15.575881  15.477414  15.503326  1890900   SCHV
# 2020-01-06  15.542196  15.549969  15.443729  15.454093  1189200   SCHV
# 2020-01-07  15.500739  15.524059  15.469644  15.518877  1076400   SCHV
# 2020-01-08  15.526648  15.599203  15.482598  15.500736  1962600   SCHV
# ...               ...        ...        ...        ...      ...    ...
# 2025-03-27  26.650000  26.770000  26.540001  26.670000  1120800   SCHV
# 2025-03-28  26.320000  26.660000  26.250000  26.590000  1483900   SCHV
# 2025-03-31  26.580000  26.709999  26.160000  26.160000  2745600   SCHV
# 2025-04-01  26.570000  26.650000  26.299999  26.520000  1533500   SCHV
# 2025-04-02  26.740000  26.770000  26.360001  26.360001  2158100   SCHV
#
# [1320 rows x 6 columns]>

# %%
# Concatenate all data into new df

new_directory = 'dse4211/dataset'
os.chdir(new_directory)

files = os.listdir(new_directory)
temp = []

for file in files:
    if file.endswith('.csv'):
        df_file_path = os.path.join(new_directory, file)
        df = pd.read_csv(df_file_path)
        temp.append(df)

temp_df = pd.concat(temp, ignore_index=True)
temp_df.to_csv('raw_data.csv', index=False)

# %%
# Data description for pre-transformed df

combined_data = pd.read_csv('dse4211/dataset/raw_data.csv')
combined_data.describe().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_8f2f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f2f6_level0_col0" class="col_heading level0 col0" >close</th>
#       <th id="T_8f2f6_level0_col1" class="col_heading level0 col1" >high</th>
#       <th id="T_8f2f6_level0_col2" class="col_heading level0 col2" >low</th>
#       <th id="T_8f2f6_level0_col3" class="col_heading level0 col3" >open</th>
#       <th id="T_8f2f6_level0_col4" class="col_heading level0 col4" >volume</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f2f6_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_8f2f6_row0_col0" class="data row0 col0" >7002.000000</td>
#       <td id="T_8f2f6_row0_col1" class="data row0 col1" >7002.000000</td>
#       <td id="T_8f2f6_row0_col2" class="data row0 col2" >7002.000000</td>
#       <td id="T_8f2f6_row0_col3" class="data row0 col3" >7002.000000</td>
#       <td id="T_8f2f6_row0_col4" class="data row0 col4" >7002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_8f2f6_row1_col0" class="data row1 col0" >10776.991247</td>
#       <td id="T_8f2f6_row1_col1" class="data row1 col1" >10999.027286</td>
#       <td id="T_8f2f6_row1_col2" class="data row1 col2" >10522.644527</td>
#       <td id="T_8f2f6_row1_col3" class="data row1 col3" >10766.865777</td>
#       <td id="T_8f2f6_row1_col4" class="data row1 col4" >9239016787.865038</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_8f2f6_row2_col0" class="data row2 col0" >21429.431326</td>
#       <td id="T_8f2f6_row2_col1" class="data row2 col1" >21873.176465</td>
#       <td id="T_8f2f6_row2_col2" class="data row2 col2" >20926.033559</td>
#       <td id="T_8f2f6_row2_col3" class="data row2 col3" >21413.619623</td>
#       <td id="T_8f2f6_row2_col4" class="data row2 col4" >18273348421.263561</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_8f2f6_row3_col0" class="data row3 col0" >9.950321</td>
#       <td id="T_8f2f6_row3_col1" class="data row3 col1" >10.302728</td>
#       <td id="T_8f2f6_row3_col2" class="data row3 col2" >9.792257</td>
#       <td id="T_8f2f6_row3_col3" class="data row3 col3" >10.297546</td>
#       <td id="T_8f2f6_row3_col4" class="data row3 col4" >13100.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_8f2f6_row4_col0" class="data row4 col0" >69.317581</td>
#       <td id="T_8f2f6_row4_col1" class="data row4 col1" >69.460717</td>
#       <td id="T_8f2f6_row4_col2" class="data row4 col2" >69.182744</td>
#       <td id="T_8f2f6_row4_col3" class="data row4 col3" >69.334272</td>
#       <td id="T_8f2f6_row4_col4" class="data row4 col4" >1566975.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_8f2f6_row5_col0" class="data row5 col0" >157.969994</td>
#       <td id="T_8f2f6_row5_col1" class="data row5 col1" >158.985753</td>
#       <td id="T_8f2f6_row5_col2" class="data row5 col2" >157.039993</td>
#       <td id="T_8f2f6_row5_col3" class="data row5 col3" >158.086683</td>
#       <td id="T_8f2f6_row5_col4" class="data row5 col4" >5780700.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_8f2f6_row6_col0" class="data row6 col0" >9604.830810</td>
#       <td id="T_8f2f6_row6_col1" class="data row6 col1" >9701.060791</td>
#       <td id="T_8f2f6_row6_col2" class="data row6 col2" >9424.333985</td>
#       <td id="T_8f2f6_row6_col3" class="data row6 col3" >9589.755371</td>
#       <td id="T_8f2f6_row6_col4" class="data row6 col4" >13839191791.250000</td>
#     </tr>
#     <tr>
#       <th id="T_8f2f6_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_8f2f6_row7_col0" class="data row7 col0" >106146.265600</td>
#       <td id="T_8f2f6_row7_col1" class="data row7 col1" >109114.882800</td>
#       <td id="T_8f2f6_row7_col2" class="data row7 col2" >105291.734400</td>
#       <td id="T_8f2f6_row7_col3" class="data row7 col3" >106147.296900</td>
#       <td id="T_8f2f6_row7_col4" class="data row7 col4" >350968000000.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Skewness and kurtosis for pre-transformed data

original_numeric_columns = combined_data.select_dtypes(include=['number']).columns
original_skewness = combined_data[original_numeric_columns].apply(scipy.stats.skew, axis=0)
original_kurtosis = combined_data[original_numeric_columns].apply(scipy.stats.kurtosis, axis=0)

print(original_skewness)
print(original_kurtosis)
# Out:
# close     2.190501
# high      2.186986
# low       2.196668
# open      2.191818
# volume    3.073929
# dtype: float64
# close      4.285111
# high       4.259793
# low        4.330565
# open       4.294175
# volume    22.960403
# dtype: float64

# %%
# Perform log-transformation on initial df features and append columns to initial df

combined_data["close_log"] = np.log(combined_data["close"])
combined_data["high_log"] = np.log(combined_data["high"])
combined_data["low_log"] = np.log(combined_data["low"])
combined_data["open_log"] = np.log(combined_data["open"])
combined_data["volume_log"] = np.log(combined_data["volume"])
combined_data["ticker"] = combined_data["ticker"]

# %%
# Encode df to transform date and ticker columns into integers
# Correlation matrix for 

encoded_df = combined_data
label_encoder = LabelEncoder()

encoded_df['date_encoded'] = label_encoder.fit_transform(encoded_df['date'])
encoded_df['ticker_encoded'] = label_encoder.fit_transform(encoded_df['ticker'])

correlation_matrix = encoded_df.select_dtypes(include=['float64', 'int64']).corr()
correlation_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_71dcf_row0_col0, #T_71dcf_row0_col1, #T_71dcf_row0_col2, #T_71dcf_row0_col3, #T_71dcf_row1_col0, #T_71dcf_row1_col1, #T_71dcf_row1_col2, #T_71dcf_row1_col3, #T_71dcf_row2_col0, #T_71dcf_row2_col1, #T_71dcf_row2_col2, #T_71dcf_row2_col3, #T_71dcf_row3_col0, #T_71dcf_row3_col1, #T_71dcf_row3_col2, #T_71dcf_row3_col3, #T_71dcf_row4_col4, #T_71dcf_row5_col5, #T_71dcf_row5_col6, #T_71dcf_row5_col7, #T_71dcf_row5_col8, #T_71dcf_row6_col5, #T_71dcf_row6_col6, #T_71dcf_row6_col7, #T_71dcf_row6_col8, #T_71dcf_row7_col5, #T_71dcf_row7_col6, #T_71dcf_row7_col7, #T_71dcf_row7_col8, #T_71dcf_row8_col5, #T_71dcf_row8_col6, #T_71dcf_row8_col7, #T_71dcf_row8_col8, #T_71dcf_row9_col9, #T_71dcf_row10_col10, #T_71dcf_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_71dcf_row0_col4, #T_71dcf_row3_col4, #T_71dcf_row4_col0, #T_71dcf_row4_col3 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_71dcf_row0_col5, #T_71dcf_row0_col6, #T_71dcf_row0_col7, #T_71dcf_row0_col8, #T_71dcf_row1_col5, #T_71dcf_row1_col6, #T_71dcf_row1_col7, #T_71dcf_row1_col8, #T_71dcf_row2_col5, #T_71dcf_row2_col6, #T_71dcf_row2_col7, #T_71dcf_row2_col8, #T_71dcf_row3_col5, #T_71dcf_row3_col6, #T_71dcf_row3_col7, #T_71dcf_row3_col8 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_71dcf_row0_col9, #T_71dcf_row1_col9, #T_71dcf_row2_col9, #T_71dcf_row3_col9, #T_71dcf_row4_col5, #T_71dcf_row4_col6, #T_71dcf_row4_col7, #T_71dcf_row4_col8 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_71dcf_row0_col10, #T_71dcf_row1_col10, #T_71dcf_row2_col10, #T_71dcf_row3_col10, #T_71dcf_row4_col10, #T_71dcf_row9_col11, #T_71dcf_row11_col0, #T_71dcf_row11_col1, #T_71dcf_row11_col2, #T_71dcf_row11_col3, #T_71dcf_row11_col4, #T_71dcf_row11_col5, #T_71dcf_row11_col6, #T_71dcf_row11_col7, #T_71dcf_row11_col8, #T_71dcf_row11_col9, #T_71dcf_row11_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_71dcf_row0_col11, #T_71dcf_row1_col11, #T_71dcf_row2_col11, #T_71dcf_row3_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_71dcf_row1_col4, #T_71dcf_row4_col1 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_71dcf_row2_col4, #T_71dcf_row4_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_71dcf_row4_col9 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_71dcf_row4_col11 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col0, #T_71dcf_row5_col1, #T_71dcf_row6_col0, #T_71dcf_row6_col1, #T_71dcf_row6_col3, #T_71dcf_row7_col0, #T_71dcf_row7_col1, #T_71dcf_row8_col0, #T_71dcf_row8_col1, #T_71dcf_row8_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col2, #T_71dcf_row5_col3, #T_71dcf_row6_col2, #T_71dcf_row7_col2, #T_71dcf_row7_col3, #T_71dcf_row8_col2 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col4, #T_71dcf_row6_col4, #T_71dcf_row7_col4, #T_71dcf_row8_col4 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col9, #T_71dcf_row6_col9, #T_71dcf_row7_col9, #T_71dcf_row8_col9, #T_71dcf_row9_col5, #T_71dcf_row9_col6, #T_71dcf_row9_col7, #T_71dcf_row9_col8 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col10, #T_71dcf_row6_col10, #T_71dcf_row7_col10, #T_71dcf_row8_col10, #T_71dcf_row9_col10 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_71dcf_row5_col11, #T_71dcf_row6_col11, #T_71dcf_row7_col11, #T_71dcf_row8_col11 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_71dcf_row9_col0, #T_71dcf_row9_col1, #T_71dcf_row9_col2, #T_71dcf_row9_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_71dcf_row9_col4 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_71dcf_row10_col0, #T_71dcf_row10_col1, #T_71dcf_row10_col2, #T_71dcf_row10_col3, #T_71dcf_row10_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_71dcf_row10_col5, #T_71dcf_row10_col6, #T_71dcf_row10_col7, #T_71dcf_row10_col8 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_71dcf_row10_col9, #T_71dcf_row10_col11 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# </style>
# <table id="T_71dcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_71dcf_level0_col0" class="col_heading level0 col0" >close</th>
#       <th id="T_71dcf_level0_col1" class="col_heading level0 col1" >high</th>
#       <th id="T_71dcf_level0_col2" class="col_heading level0 col2" >low</th>
#       <th id="T_71dcf_level0_col3" class="col_heading level0 col3" >open</th>
#       <th id="T_71dcf_level0_col4" class="col_heading level0 col4" >volume</th>
#       <th id="T_71dcf_level0_col5" class="col_heading level0 col5" >close_log</th>
#       <th id="T_71dcf_level0_col6" class="col_heading level0 col6" >high_log</th>
#       <th id="T_71dcf_level0_col7" class="col_heading level0 col7" >low_log</th>
#       <th id="T_71dcf_level0_col8" class="col_heading level0 col8" >open_log</th>
#       <th id="T_71dcf_level0_col9" class="col_heading level0 col9" >volume_log</th>
#       <th id="T_71dcf_level0_col10" class="col_heading level0 col10" >date_encoded</th>
#       <th id="T_71dcf_level0_col11" class="col_heading level0 col11" >ticker_encoded</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71dcf_level0_row0" class="row_heading level0 row0" >close</th>
#       <td id="T_71dcf_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_71dcf_row0_col1" class="data row0 col1" >0.999750</td>
#       <td id="T_71dcf_row0_col2" class="data row0 col2" >0.999691</td>
#       <td id="T_71dcf_row0_col3" class="data row0 col3" >0.999415</td>
#       <td id="T_71dcf_row0_col4" class="data row0 col4" >0.769575</td>
#       <td id="T_71dcf_row0_col5" class="data row0 col5" >0.845675</td>
#       <td id="T_71dcf_row0_col6" class="data row0 col6" >0.845727</td>
#       <td id="T_71dcf_row0_col7" class="data row0 col7" >0.845551</td>
#       <td id="T_71dcf_row0_col8" class="data row0 col8" >0.845619</td>
#       <td id="T_71dcf_row0_col9" class="data row0 col9" >0.797731</td>
#       <td id="T_71dcf_row0_col10" class="data row0 col10" >-0.001681</td>
#       <td id="T_71dcf_row0_col11" class="data row0 col11" >-0.318169</td>
#     </tr>
#     <tr>
#       <th id="T_71dcf_level0_row1" class="row_heading level0 row1" >high</th>
#       <td id="T_71dcf_row1_col0" class="data row1 col0" >0.999750</td>
#       <td id="T_71dcf_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_71dcf_row1_col2" class="data row1 col2" >0.999519</td>
#       <td id="T_71dcf_row1_col3" class="data row1 col3" >0.999729</td>
#       <td id="T_71dcf_row1_col4" class="data row1 col4" >0.774151</td>
#       <td id="T_71dcf_row1_col5" class="data row1 col5" >0.845706</td>
#       <td id="T_71dcf_row1_col6" class="data row1 col6" >0.845839</td>
#       <td id="T_71dcf_row1_col7" class="data row1 col7" >0.845592</td>
#       <td id="T_71dcf_row1_col8" class="data row1 col8" >0.845739</td>
#       <td id="T_71dcf_row1_col9" class="data row1 col9" >0.798264</td>
#       <td id="T_71dcf_row1_col10" class="data row1 col10" >-0.001783</td>
#       <td id="T_71dcf_row1_col11" class="data row1 col11" >-0.318174</td>
#     </tr>
#     <tr>
#       <th id="T_71dcf_level0_row2" class="row_heading level0 row2" >low</th>
#       <td id="T_71dcf_row2_col0" class="data row2 col0" >0.999691</td>
#       <td id="T_71dcf_row2_col1" class="data row2 col1" >0.999519</td>
#       <td id="T_71dcf_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_71dcf_row2_col3" class="data row2 col3" >0.999604</td>
#       <td id="T_71dcf_row2_col4" class="data row2 col4" >0.763228</td>
#       <td id="T_71dcf_row2_col5" class="data row2 col5" >0.845378</td>
#       <td id="T_71dcf_row2_col6" class="data row2 col6" >0.845440</td>
#       <td id="T_71dcf_row2_col7" class="data row2 col7" >0.845352</td>
#       <td id="T_71dcf_row2_col8" class="data row2 col8" >0.845398</td>
#       <td id="T_71dcf_row2_col9" class="data row2 col9" >0.796838</td>
#       <td id="T_71dcf_row2_col10" class="data row2 col10" >-0.001549</td>
#       <td id="T_71dcf_row2_col11" class="data row2 col11" >-0.318088</td>
#     </tr>
#     <tr>
#       <th id="T_71

# %%
encoded_df.to_csv('asset_portfolio_latest.csv', index=False)

# %%
# Create separate dataset with log-transformed features

asset_portfolio = pd.DataFrame()

asset_portfolio["date"] = combined_data["date"]
asset_portfolio["close_log"] = np.log(combined_data["close"])
asset_portfolio["high_log"] = np.log(combined_data["high"])
asset_portfolio["low_log"] = np.log(combined_data["low"])
asset_portfolio["open_log"] = np.log(combined_data["open"])
asset_portfolio["volume_log"] = np.log(combined_data["volume"])
asset_portfolio["ticker"] = combined_data["ticker"]

asset_portfolio.describe().style
# Out:
# <style type="text/css">
# </style>
# <table id="T_30d62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30d62_level0_col0" class="col_heading level0 col0" >close_log</th>
#       <th id="T_30d62_level0_col1" class="col_heading level0 col1" >high_log</th>
#       <th id="T_30d62_level0_col2" class="col_heading level0 col2" >low_log</th>
#       <th id="T_30d62_level0_col3" class="col_heading level0 col3" >open_log</th>
#       <th id="T_30d62_level0_col4" class="col_heading level0 col4" >volume_log</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30d62_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_30d62_row0_col0" class="data row0 col0" >7002.000000</td>
#       <td id="T_30d62_row0_col1" class="data row0 col1" >7002.000000</td>
#       <td id="T_30d62_row0_col2" class="data row0 col2" >7002.000000</td>
#       <td id="T_30d62_row0_col3" class="data row0 col3" >7002.000000</td>
#       <td id="T_30d62_row0_col4" class="data row0 col4" >7002.000000</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_30d62_row1_col0" class="data row1 col0" >5.992461</td>
#       <td id="T_30d62_row1_col1" class="data row1 col1" >6.001354</td>
#       <td id="T_30d62_row1_col2" class="data row1 col2" >5.982202</td>
#       <td id="T_30d62_row1_col3" class="data row1 col3" >5.992099</td>
#       <td id="T_30d62_row1_col4" class="data row1 col4" >17.348181</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_30d62_row2_col0" class="data row2 col0" >2.809996</td>
#       <td id="T_30d62_row2_col1" class="data row2 col1" >2.816529</td>
#       <td id="T_30d62_row2_col2" class="data row2 col2" >2.802139</td>
#       <td id="T_30d62_row2_col3" class="data row2 col3" >2.809538</td>
#       <td id="T_30d62_row2_col4" class="data row2 col4" >4.276798</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_30d62_row3_col0" class="data row3 col0" >2.297605</td>
#       <td id="T_30d62_row3_col1" class="data row3 col1" >2.332409</td>
#       <td id="T_30d62_row3_col2" class="data row3 col2" >2.281592</td>
#       <td id="T_30d62_row3_col3" class="data row3 col3" >2.331906</td>
#       <td id="T_30d62_row3_col4" class="data row3 col4" >9.480368</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_30d62_row4_col0" class="data row4 col0" >4.238699</td>
#       <td id="T_30d62_row4_col1" class="data row4 col1" >4.240761</td>
#       <td id="T_30d62_row4_col2" class="data row4 col2" >4.236751</td>
#       <td id="T_30d62_row4_col3" class="data row4 col3" >4.238939</td>
#       <td id="T_30d62_row4_col4" class="data row4 col4" >14.264658</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_30d62_row5_col0" class="data row5 col0" >5.062405</td>
#       <td id="T_30d62_row5_col1" class="data row5 col1" >5.068815</td>
#       <td id="T_30d62_row5_col2" class="data row5 col2" >5.056501</td>
#       <td id="T_30d62_row5_col3" class="data row5 col3" >5.063144</td>
#       <td id="T_30d62_row5_col4" class="data row5 col4" >15.570035</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_30d62_row6_col0" class="data row6 col0" >9.170021</td>
#       <td id="T_30d62_row6_col1" class="data row6 col1" >9.179991</td>
#       <td id="T_30d62_row6_col2" class="data row6 col2" >9.151049</td>
#       <td id="T_30d62_row6_col3" class="data row6 col3" >9.168451</td>
#       <td id="T_30d62_row6_col4" class="data row6 col4" >23.350770</td>
#     </tr>
#     <tr>
#       <th id="T_30d62_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_30d62_row7_col0" class="data row7 col0" >11.572573</td>
#       <td id="T_30d62_row7_col1" class="data row7 col1" >11.600157</td>
#       <td id="T_30d62_row7_col2" class="data row7 col2" >11.564490</td>
#       <td id="T_30d62_row7_col3" class="data row7 col3" >11.572583</td>
#       <td id="T_30d62_row7_col4" class="data row7 col4" >26.583961</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Skewness and kurtosis for log-tranformed features

transformed_numeric_columns = asset_portfolio.select_dtypes(include=['number']).columns
transformed_skewness = asset_portfolio[transformed_numeric_columns].apply(scipy.stats.skew, axis=0)
transformed_kurtosis = asset_portfolio[transformed_numeric_columns].apply(scipy.stats.kurtosis, axis=0)

print(transformed_skewness)
#print(transformed_kurtosis)
# Out:
# close_log     0.816603
# high_log      0.817836
# low_log       0.815180
# open_log      0.816577
# volume_log    0.834967
# dtype: float64
# close_log    -0.886818
# high_log     -0.886920
# low_log      -0.886500
# open_log     -0.886573
# volume_log   -0.980303
# dtype: float64

# %%
## Plot original close prices

# Convert date column to datetime
combined_data["date"] = pd.to_datetime(combined_data["date"], format="%d/%m/%y") 

# Set the date column as the index
combined_data.set_index('date', inplace=True)

# Create a line plot for each ticker
plt.figure(figsize=(12, 6))

for ticker, group in combined_data.groupby('ticker'):
    plt.plot(group.index, group['close'], label=ticker)


# Adding titles and labels
plt.title('Raw Asset Closing Prices Over Time')
plt.xlabel('Year')
plt.ylabel('Raw Close Price')
plt.legend(title='Ticker')
plt.grid()
plt.xticks(rotation=45)  

# Show the plot
plt.show()

# %%
## Plot log-transformed close prices

# Convert date column to datetime
asset_portfolio["date"] = pd.to_datetime(asset_portfolio["date"], format="%d/%m/%y") 

# Set the date column as the index
asset_portfolio.set_index('date', inplace=True)

# Create a line plot for each ticker
plt.figure(figsize=(12, 6))

for ticker, group in asset_portfolio.groupby('ticker'):
    plt.plot(group.index, group['close_log'], label=ticker)


# Adding titles and labels
plt.title('Log-Transformed Asset Closing Prices Over Time')
plt.xlabel('Year')
plt.ylabel('Log-Transformed Close Price')
plt.legend(title='Ticker')
plt.grid()
plt.xticks(rotation=45)  

# Show the plot
plt.show()

# %%
portfolio_with_features = pd.read_csv('dse4211/dataset/asset_portfolio_with_featuresv2.csv')
portfolio_with_features["date"] = pd.to_datetime(portfolio_with_features["date"], format='mixed', dayfirst=True)

# %%
portfolio_with_features.set_index('date', inplace=True)
portfolio_with_features = portfolio_with_features.sort_index()
#print(portfolio_with_features.head())
# Out:
#                   close         high          low         open        volume  \
# date
# 2020-01-17   146.580002   146.990005   146.309998   146.509995  1.112110e+07
# 2020-01-17    73.061028    73.069691    72.974412    72.991733  3.090600e+06
# 2020-01-17  8929.038086  8958.122070  8677.316406  8725.209961  3.637214e+10
# 2020-01-17    16.317472    16.336189    16.296085    16.320147  9.954000e+05
# 2020-01-18  8942.808594  9012.198242  8827.332031  8927.211914  3.233777e+10
#
#             close_log  high_log   low_log  open_log  volume_log  ...  \
# date                                                             ...
# 2020-01-17   4.987571  4.990365  4.985728  4.987094   16.224355  ...
# 2020-01-17   4.291295  4.291414  4.290109  4.290346   14.943876  ...
# 2020-01-17   9.097064  9.100316  9.068468  9.073972   24.317069  ...
# 2020-01-17   2.792236  2.793383  2.790925  2.792400   13.810900  ...
# 2020-01-18   9.098605  9.106334  9.085608  9.096859   24.199502  ...
#
#            volatility_30        MACD  MACD_signal  MACD_histogram  \
# date
# 2020-01-17    178.900890 -247.182826  -344.533183       97.350357
# 2020-01-17    178.894748 -399.469528  -355.520452      -43.949075
# 2020-01-17    178.423788  192.229597  -245.970442      438.200040
# 2020-01-17    179.038390  -57.365378  -208.249429      150.884052
# 2020-01-18    197.366183  459.821502   -74.635243      534.456745
#
#             Bollinger_Upper  Bollinger_Lower  Bollinger_Bandwidth  \
# date
# 2020-01-17     10475.911280     -5279.164719          15755.07600
# 2020-01-17     10477.124750     -5287.763093          15764.88785
# 2020-01-17     10660.163190     -5381.651481          16041.81467
# 2020-01-17      9884.684112     -5423.790070          15308.47418
# 2020-01-18     10813.225460     -5459.663854          16272.88931
#
#                  ATR_14   Momentum_5   Volume_MA_5
# date
# 2020-01-17  3808.355923    73.467026  6.267386e+09
# 2020-01-17  3808.400926    -0.008652  6.267048e+09
# 2020-01-17  3814.004193  8782.728088  1.354026e+10
# 2020-01-17  3825.282130     0.026737  1.354027e+10
# 2020-01-18  4462.644355   219.022461  1.374502e+10
#
# [5 rows x 25 columns]

# %%
#Augmented Dickey-Fuller (ADF) Test
adf_test = adfuller(portfolio_with_features['close_log'])
print(f"ADF Statistic: {adf_test[0]}")
print(f"p-value: {adf_test[1]}")

if adf_test[1] < 0.05:
    print("The time series is stationary.")
else:
    print("The time series is not stationary (differencing may be needed).")
# Out:
# ADF Statistic: -7.225723025984675
# p-value: 2.055597548068169e-10
# The time series is stationary.

# %%
#Decompose Time Series
result = seasonal_decompose(portfolio_with_features['close_log'], model='additive', period=30)  # Adjust period as needed
result.plot()
plt.show()

# %%
# Check for lags using ACF & PACF
plt.figure(figsize=(12,5))
plot_acf(portfolio_with_features['close_log'].dropna(), lags=40)  # Autocorrelation
plot_pacf(portfolio_with_features['close_log'].dropna(), lags=40)  # Partial Autocorrelation
plt.show()

# %%
# Fit ARIMA Model (adjust p, d, q based on ACF/PACF)
model = ARIMA(portfolio_with_features['close_log'], order=(1,1,1))  # Example order (p,d,q)
model_fit = model.fit()

# Forecast for the next 90 days
forecast = model_fit.forecast(steps=300)

# Generate future date range
future_dates = pd.date_range(portfolio_with_features.index[-1], periods=300, freq='D')

# Plot Forecast
plt.figure(figsize=(12,6))
plt.plot(portfolio_with_features.index, portfolio_with_features['close_log'], label='Actual Closing Price', color='blue')
plt.plot(future_dates, forecast, label='90-Day Forecast', linestyle='dashed', color='red')

plt.xlabel('Date')
plt.ylabel('Log Closing Price')
plt.title('ARIMA 90-Day Forecast')
plt.legend()
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Plot Bollinger bands for pre-transformed close prices
plt.figure(figsize=(12, 6))

# Main axis
ax = plt.gca()
line1, = ax.plot(portfolio_with_features['date'], portfolio_with_features['close'], label='Closing Price', color='blue')
line2, = ax.plot(portfolio_with_features['date'], portfolio_with_features['Bollinger_Upper'], label='Upper Band', linestyle='dashed', color='red')
line3, = ax.plot(portfolio_with_features['date'], portfolio_with_features['Bollinger_Lower'], label='Lower Band', linestyle='dashed', color='green')

ax.set_xlabel('Date')
ax.set_ylabel('Closing Price ($)')

# Secondary y-axis for Bandwidth
ax2 = ax.twinx()
line4, = ax2.plot(portfolio_with_features['date'], portfolio_with_features['Bollinger_Bandwidth'], label='Bandwidth', color='purple', alpha=0.5)
ax2.set_ylabel('Bandwidth')

# Combine legends from both axes
lines = [line1, line2, line3, line4]
labels = [l.get_label() for l in lines]
ax.legend(lines, labels, loc='upper left')

plt.title('Bollinger Bands')
plt.show()
